# %%
import pandas as pd

# %%
df = pd.read_csv("./data/data_best_ratings.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 imdb_title_id                original_title  year  \
# 0           0     tt0017938        La glace à trois faces  1983
# 1           1     tt0052205  The Small World of Sammy Lee  1963
# 2           2     tt0052607       The Battle of the Sexes  1960
# 3           3     tt0052698           Classe tous risques  1960
# 4           4     tt0052721          Darbuján a Pandrhola  1960
#
#   date_published                  genre  duration         country  \
# 0     1983-03-13         Drama, Romance        45          France
# 1     1963-04-01                  Drama       107              UK
# 2     1960-08-22                 Comedy        84              UK
# 3     1960-04-01  Crime, Drama, Romance       110   France, Italy
# 4     1960-06-10        Comedy, Fantasy        80  Czechoslovakia
#
#           language          director  \
# 0     None, French      Jean Epstein
# 1          English        Ken Hughes
# 2          English  Charles Crichton
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17572 entries, 0 to 17571
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      17572 non-null  int64
#  1   imdb_title_id   17572 non-null  object
#  2   original_title  17572 non-null  object
#  3   year            17572 non-null  object
#  4   date_published  17572 non-null  object
#  5   genre           17572 non-null  object
#  6   duration        17572 non-null  int64
#  7   country         17572 non-null  object
#  8   language        17572 non-null  object
#  9   director        17572 non-null  object
#  10  actors          17572 non-null  object
#  11  description     17572 non-null  object
#  12  avg_vote        17572 non-null  float64
#  13  votes           17572 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 1.9+ MB

# %%
new_df = df[df['year']>"2000"]

# %%
new_df
# Out:
#        Unnamed: 0 imdb_title_id  \
# 1961         1961     tt0069049
# 6260         6260     tt0118926
# 6440         6440     tt0120679
# 6441         6441     tt0120681
# 6452         6452     tt0120737
# ...           ...           ...
# 17567       17567     tt9894394
# 17568       17568     tt9894440
# 17569       17569     tt9900060
# 17570       17570     tt9911196
# 17571       17571     tt9914942
#
#                                           original_title  year date_published  \
# 1961                          The Other Side of the Wind  2018     2018-11-02
# 6260                                 The Dancer Upstairs  2002     2003-01-10
# 6440                                               Frida  2002     2003-01-17
# 6441                                           From Hell  2001     2001-12-21
# 6452   The Lord of the Rings: The Fellowship of the Ring  2001     2002-01-18
# ...                                                  ...   ...            ...
# ...

# %%
new_df.to_csv
